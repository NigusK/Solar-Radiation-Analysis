# %%
import pandas as pd
import os
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Load data

# %%
df_benin =pd.read_csv('data/benin-malanville.csv')
df_sierraleone =pd.read_csv('data/sierraleone-bumbuna.csv')
df_togo =pd.read_csv('data/togo-dapaong_qc.csv')

# %% [markdown]
# ### Import Modules

# %%
from script.EDA import EDA
analysys=EDA()

# %% [markdown]
# ### Check Missing Data

# %%
#check missing values in each column
analysys.check_missing_value(df_benin)
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
analysys.check_missing_value(df_sierraleone)
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
analysys.check_missing_value(df_togo)
# Out:
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %% [markdown]
# ### Removing negative values
# Since the negative values have no meaning and they are the result of measurement errors , they should be replaced with zero

# %%
#Replacing negative values in 'GHI', 'DNI', 'DHI' with zero since they are measuremet errors
df_benin_cleaned=analysys.replace_nagative_values(df_benin)
df_sierraleone_cleaned=analysys.replace_nagative_values(df_sierraleone)
df_togo_cleaned=analysys.replace_nagative_values(df_togo)

# %% [markdown]
# ### Summary Statistics

# %%
#summary statistics
analysys.summary_statistics(df_benin_cleaned)
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      241.958821     167.441866     116.993033     236.536448
# std       330.101787     261.547532     157.463619     326.810945
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.800000       0.000000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.600000
# max      1413.000000     952.300000     759.200000    1215.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.764065      28.179683      54.487969       2.083517
# std       316.347871       5.924297      28.073069       1.521833
# min         0.000000      11.000000       2.100000       0.000000
# 25%         0.000000      24.200000      28.800000       1.000000
# 50%         4.300000      28.000000      55.100000       1.900000
# 75%       447.600000      32.300000      80.100000       3.000000
# max      1177.000000      43.800000     100.000000       6.900000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        2.755926       0.473390     153.435172       8.582407
# std         1.912856       0.273395     102.332842       6.385864
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.300000       0.400000      59.000000       3.700000
# 50%         2.600000       0.500000     181.000000       8.600000
# 75%         3.900000       0.600000     235.100000      12.300000
# max         8.700000       4.200000     360.000000      99.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      994.197199       0.000923       0.001905      35.246026
# std         2.474993       0.030363       0.037115      14.807258
# min       985.000000       0.000000       0.000000       9.000000
# 25%       993.000000       0.000000       0.000000      24.200000
# 50%       994.000000       0.000000       0.000000      30.000000
# 75%       996.000000       0.000000       0.000000      46.900000
# max      1003.000000       1.000000       2.500000      81.000000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.471736       NaN
# std        12.348743       NaN
# min         8.100000       NaN
# 25%        23.600000       NaN
# 50%        28.900000       NaN
# 75%        41.500000       NaN
# max        72.500000       NaN

# %%
analysys.summary_statistics(df_sierraleone_cleaned)
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      204.406778     116.523731     116.273677     203.665472
# std       296.787520     218.573992     157.020868     296.024918
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.300000       0.000000       0.000000       3.600000
# 75%       362.400000     107.000000     224.700000     353.800000
# max      1499.000000     946.000000     892.000000    1109.200000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      194.461795      26.319394      79.448857       1.109028
# std       282.875441       4.398605      20.520775       1.157065
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       338.500000      29.400000      96.700000       1.900000
# max      1064.000000      39.900000     100.000000       4.800000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.645261       0.363823     133.044668       7.172220
# std         1.509348       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max         6.400000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.593091       NaN
# std        12.009161       NaN
# min        11.100000       NaN
# 25%        23.800000       NaN
# 50%        26.900000       NaN
# 75%        41.300000       NaN
# max        70.400000       NaN

# %%
analysys.summary_statistics(df_togo_cleaned)
# Out:
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      231.718786     151.258469     116.444352     225.884852
# std       321.691953     250.956962     156.520714     316.938883
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         2.100000       0.000000       2.500000       4.400000
# 75%       442.400000     246.400000     215.700000     421.900000
# max      1424.000000    1004.500000     805.700000    1178.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      219.188607      27.751788      55.013160       2.331217
# std       307.332783       4.758023      28.778732       1.388161
# min         0.000000      14.900000       3.300000       0.000000
# 25%         0.000000      24.200000      26.500000       1.400000
# 50%         4.300000      27.200000      59.300000       2.200000
# 75%       410.100000      31.100000      80.800000       3.200000
# max      1143.000000      41.400000      99.800000       6.700000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        3.175654       0.557740     161.741845      10.559568
# std         1.770292       0.268923      91.877217       5.915490
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.900000       0.400000      74.800000       6.900000
# 50%         2.900000       0.500000     199.100000      10.800000
# 75%         4.300000       0.700000     233.500000      14.100000
# max         8.800000       4.700000     360.000000      86.900000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      975.915242       0.000535       0.001382      32.444403
# std         2.153977       0.023116       0.026350      10.998334
# min       968.000000       0.000000       0.000000      13.100000
# 25%       975.000000       0.000000       0.000000      23.900000
# 50%       976.000000       0.000000       0.000000      28.400000
# 75%       977.000000       0.000000       0.000000      40.600000
# max       983.000000       1.000000       2.300000      70.400000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       33.543330       NaN
# std        12.769277       NaN
# min        13.100000       NaN
# 25%        23.600000       NaN
# 50%        28.400000       NaN
# 75%        43.000000       NaN
# max        94.600000       NaN

# %% [markdown]
# ### Impute Outliers

# %%
df_benin_cleaned=analysys.outliers_fun(df_benin_cleaned,['ModA', 'ModB','WS', 'WSgust'])
df_sierraleone_cleaned=analysys.outliers_fun(df_sierraleone_cleaned,['ModA', 'ModB','WS', 'WSgust'])
df_togo_cleaned=analysys.outliers_fun(df_togo_cleaned,['ModA', 'ModB','WS', 'WSgust'])

# %% [markdown]
# ### Compare the mean, median and standard deviation of 'GHI', 'DNI', 'DHI' of the sites

# %%
analysys.mean_median_std_comparison(df_benin_cleaned,df_sierraleone_cleaned,df_togo_cleaned)

# %% [markdown]
# ## Time Series Analysis

# %% [markdown]
# ### Time series analysis of GHI, DNI, DHI and Tamb over an hour

# %%
#Time series analysis of GHI, DNI, DHI and Tamb over an hour
analysys.plot_over_an_hour(df_benin_cleaned,df_sierraleone_cleaned,df_togo_cleaned)

# %% [markdown]
# ### Time series analysis of GHI, DNI, DHI and Tamb over a day

# %%
analysys.plot_over_a_day(df_benin_cleaned,df_sierraleone_cleaned,df_togo_cleaned)

# %% [markdown]
# ### Time series analysis of GHI, DNI, DHI and Tamb over a month

# %%
#Time series analysis of GHI, DNI, DHI and Tamb over a month
analysys.plot_over_a_month(df_benin_cleaned,df_sierraleone_cleaned,df_togo_cleaned)

# %% [markdown]
# ### Plot Daily Mean

# %%
analysys.plot_daily_mean(df_benin_cleaned,df_sierraleone_cleaned,df_togo_cleaned)
